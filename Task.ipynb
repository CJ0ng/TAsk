# %%
import pandas as pd
import pyarrow.parquet as pq
import connectorx as cx
from io import StringIO

# %%
a_file = 'mt4_uk8-2023-510208161.parquet'
table= pq.read_table(a_file)
df = table.to_pandas()
df
# Out:
#         login  trade_date  server_id  today_deposit  today_withdrawal  \
# 0   510208161  2023-06-07         49       534.9575               0.0
# 1   510208161  2023-06-08         49         0.0000               0.0
# 2   510208161  2023-06-09         49         0.0000               0.0
# 3   510208161  2023-06-10         49         0.0000               0.0
# 4   510208161  2023-06-11         49         0.0000               0.0
# ..        ...         ...        ...            ...               ...
# 94  510208161  2023-09-09         49         0.0000               0.0
# 95  510208161  2023-09-10         49         0.0000               0.0
# 96  510208161  2023-09-11         49         0.0000               0.0
# 97  510208161  2023-09-12         49         0.0000               0.0
# 98  510208161  2023-09-13         49         0.0000               0.0
#
#        balance  today_closed_pnl  total_unrealized_pnl  current_credit  \
# ...

# %%
# filtered_df = df[
#     (df['today_closed_pnl'] != 0) &
#     (df['today_deposit'] != 0 ) &
#     (df['today_swaps'] != 0 ) &
#     (df['total_deposit'] != df['today_deposit'])]
filtered_df = df[df['login'] == 3001153]
filtered_df.tail(20)
# Out:
#         login  trade_date  server_id  today_deposit  today_withdrawal  \
# 69  510208161  2023-08-15         49            0.0               0.0
# 70  510208161  2023-08-16         49            0.0               0.0
# 71  510208161  2023-08-17         49            0.0               0.0
# 72  510208161  2023-08-18         49            0.0               0.0
# 75  510208161  2023-08-21         49            0.0               0.0
# 76  510208161  2023-08-22         49            0.0               0.0
# 77  510208161  2023-08-23         49            0.0               0.0
# 78  510208161  2023-08-24         49            0.0               0.0
# 79  510208161  2023-08-25         49            0.0               0.0
# 82  510208161  2023-08-28         49            0.0               0.0
# 83  510208161  2023-08-29         49            0.0               0.0
# 85  510208161  2023-08-31         49            0.0               0.0
# ...

# %%
df.iloc[255]
# Out:
# login                                   3001153
# trade_date                           2023-09-13
# today_deposit                               0.0
# today_withdrawal                            0.0
# server_id                                    32
# balance                          1376893.975498
# today_closed_pnl                   -3200.464511
# total_unrealized_pnl             -141756.673892
# current_credit                              0.0
# equity                           1235137.301606
# today_swaps                         -908.669325
# today_volume_usd_done                 15.732865
# total_commission                    -199.807373
# total_deposit                     954837.622434
# total_realized_pnl                452293.381773
# total_swaps                      -169663.664077
# total_withdrawal                            0.0
# t_m1_pnl_delta                    -16065.475688
# historical_pnl                    310536.707881
# mtd_pnl_delta                     -27850.145555
# ...

# %%
#Output sl data
selected_row = df.iloc[255:256]
row_table = selected_row.to_string(index=False, header=True, justify='left')
row_df = pd.read_csv(StringIO(row_table), delimiter='\s+')
row_df.to_excel("output_excel_file5.xlsx", index=False)

# %%
#EQUITY
mysql_url = "mysql://DataMY_read:qeC18ub3n3@192.168.1.179:3306/brad"
xlogin = input('Login: ')
xdate = input('Date: (yyyy-mm-dd)')
query = f"""
SELECT login, date, coalesce(balance*(equity_in_usd/equity),0)AS balance, equity_in_usd AS equity , coalesce(close_pnl*(equity_in_usd/equity ),0) AS ClosePNL , coalesce(floating_pnl*(equity_in_usd/equity),0 )AS FloatingPNL  , credit_in_usd, floating_pnl *(equity_in_usd/equity) AS unrealized_pnl, (close_pnl*(equity_in_usd/equity)+ unrealize_pnl*(equity_in_usd/equity))  as Historical_pnl
FROM brad.bbook_v_1_2021
where db = 'VUK8'
and login = {xlogin}
and `date` = '{xdate}'
"""
db1 = cx.read_sql(mysql_url, query)


#VFX
mysql_url = "mysql://DataMY_read:qeC18ub3n3@192.168.1.179:3306/vfx-vig"
query = f"""
SELECT deposit, withdrawal, (m_swap + s_swap) AS today_swap, (m_volume+s_volume)*2 as today_volume, (m_commission + s_commission) AS today_commission
FROM `vfx-vig`.detail d 
where db = 'VUK8'
and login = {xlogin}
and `date` = '{xdate}'
"""
db2 = cx.read_sql(mysql_url, query)


# #OUTPUT
pd.set_option('display.width', 1000)
combined_db = pd.concat([db1, db2], axis = 1)
print(combined_db)
# Out:
# Empty DataFrame
# Columns: [login, date, balance, equity, ClosePNL, FloatingPNL, credit_in_usd, unrealized_pnl, Historical_pnl, deposit, withdrawal, today_swap, today_volume, today_commission]
# Index: []

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
x = datetime.today().date()
x = x-timedelta(days = 1)
x = x.strftime('%Y-%m-%d')
x
# Out:
# '2024-01-17'
